# %% [markdown]
# ## This is the test
#
# #Note that the environment (**.py** and **Terminal**) should be the same!
#
# [See](https://github.com/Anran13/postgres_learning/tree/main/image/pip_python.png)
